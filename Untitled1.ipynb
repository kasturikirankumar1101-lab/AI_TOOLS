# %% [markdown]
# <a href="https://colab.research.google.com/github/kasturikirankumar1101-lab/AI_TOOLS/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/kasturikirankumar1101-lab/AI_TOOLS.git
# %cd AI_TOOLS

# !cp /content/HisttoryIQHelp.ipynb .

# !git add .
# !git commit -m "Added notebook from Colab"
# !git push
# Out:
# Cloning into 'AI_TOOLS'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/AI_TOOLS
# cp: cannot stat '/content/HisttoryIQHelp.ipynb': No such file or directory
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@6a4143c77904.(none)')
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.email "kasturi.kirankumar1101@gmail.com"
# !git config --global user.name "Kiran Kasturi"



# !git clone https://github.com/kasturikirankumar1101-lab/AI_TOOLS.git
# %cd AI_TOOLS

# !cp /content/HisttoryIQHelp.ipynb .

# !git add .
# !git commit -m "Added notebook from Colab"
# !git push
# Out:
# Cloning into 'AI_TOOLS'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/AI_TOOLS/AI_TOOLS
# cp: cannot stat '/content/HisttoryIQHelp.ipynb': No such file or directory
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
import atexit

def auto_push():
    # !git add .
    # !git commit -m "Auto-save"
    # !git push

atexit.register(auto_push)
# Out:
# <function __main__.auto_push()>
